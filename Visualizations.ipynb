# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4], [1,4,9,16])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import pandas.tools.rplot as rplot

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16],linewidth=4.0) # increasing # the line width
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16],linewidth=4.0, color='blue', label="Dataset 1") # increasing # the line width
plt.plot([1, 2, 3, 6], [2, 7, 9, 16],linewidth=4.0, color='green', label="Dataset 2")
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16],linewidth=4.0, color='blue', label="Dataset 1") # increasing # the line width
plt.scatter([1, 2, 3, 6], [2, 7, 9, 16],linewidth=4.0, color='green', label="Dataset 2")
plt.show()

# %%
x = np.linspace(0, 10, 100)
plt.plot(x, x, label='linear')
plt.legend()
plt.show()

# %%
line, = plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
line.set_linestyle('--')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
line, = plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.setp(line,color='r',linewidth=2.0,linestyle="--")
plt.show()

# %%
x = np.linspace(0,10,100)
y = x**2
y = np.sqrt(x)
plt.plot(x,y,'r')
plt.show()

# %%
x = np.linspace(0,10,100)
y = x**2
y = np.sqrt(x)
plt.subplot(1,2,1)
plt.plot(x,y,'b')
plt.subplot(1,2,2)
plt.plot(x,y,'g')
plt.show()

# %%
#multiple plots
p1 = np.arange(0.0, 30.0, 0.1)
plt.subplot(211)
plt.plot(p1,np.sin(p1)/p1,'r--')
plt.subplot(212)
plt.plot(p1, np.cos(p1), 'b--')
plt.show()
# Out:
# C:\Users\Poori\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], color='b', linewidth=3)
ax.scatter([2, 3.8, 1.2, 2.5], [26, 25, 9, 22], color='r', marker='^')
ax.set_xlim(0.5, 4.5)
plt.show()
fig.savefig("scatterANDline.png")

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(np.linspace(0, 1, 5), np.linspace(0, 5, 5))
ax.set_xlabel('X') 
ax.set_ylabel("Y") 
ax.set_title("scatter plot") 
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ax1.bar([1,2,3],[3,4,5])
ax2.barh([0.5,1,2.5],[0,1,2])

plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(131)
ax2 = fig.add_subplot(132)
ax3 = fig.add_subplot(133)

ax1.bar([1,2,3],[3,4,5])
ax2.barh([0.5,1,2.5],[0,1,2])
ax2.axhline(0.45)
ax1.axvline(0.65)
ax3.scatter(np.linspace(0, 1, 5), np.linspace(0, 5, 5))

plt.show()

# %%
n=np.random.random_sample((5,))
plt.bar(np.arange(len(n)),n)
plt.xlabel('Indices')
plt.ylabel('Value')
plt.text(1, 0.8, r'$\mu=' + str(np.round(np.mean(n), 2)) + ' $') #1,.7 are locations at which we have to keep the values
plt.show()

# %%
plt.style.use('ggplot')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
#multiple plots
plt.style.use('ggplot')
p1 = np.arange(0.0, 30.0, 0.1)
plt.subplot(211)
plt.plot(p1,np.sin(p1)/p1,'r--')
plt.subplot(212)
plt.plot(p1, np.cos(p1), 'b--')
plt.show()
# Out:
# C:\Users\Poori\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """

# %%
plt.style.use('fivethirtyeight')
p1 = np.arange(0.0, 30.0, 0.1)
plt.subplot(211)
plt.plot(p1,np.sin(p1)/p1,'r--')
plt.subplot(212)
plt.plot(p1, np.cos(p1), 'b--')
plt.show()
# Out:
# C:\Users\Poori\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
with plt.style.context(('dark_background')):
    plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
np.random.seed(10)
with plt.style.context(('dark_background')):
    box_data_1 = np.random.normal(100, 10, 200)
    box_data_2 = np.random.normal(80, 30, 200)
    box_data_3 = np.random.normal(90, 20, 200)
    data_to_plot = [box_data_1, box_data_2, box_data_3]
    bp = plt.boxplot(data_to_plot)

# %%
np.random.seed(10)
box_data_1 = np.random.normal(100, 10, 200)
box_data_2 = np.random.normal(80, 30, 200)
box_data_3 = np.random.normal(90, 20, 200)
data_to_plot = [box_data_1, box_data_2, box_data_3]
bp = plt.boxplot(data_to_plot)

# %%
#heat maps
data = np.random.rand(10,6)
#rows = list('ZYXWVUTSRQ') #Ylabel
#columns = list('ABCDEF') #Xlabel
plt.pcolor(data)
plt.show()

# %%
#np.random.rand(10,6) #with 10 lists with each 6 elements

# %%
plt.pcolor(data)
plt.xticks(np.arange(0,6)+0.5,columns)
plt.yticks(np.arange(0,10)+0.5,rows)
plt.show()

# %%
print(np.arange(0,6)+0.5)
print(np.arange(0,10)+0.5)
# Out:
# [0.5 1.5 2.5 3.5 4.5 5.5]
# [0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5]

# %%
plt.pcolor(data,cmap=plt.cm.Reds,edgecolors='k')
plt.xticks(np.arange(0,6)+0.5,columns)
plt.yticks(np.arange(0,10)+0.5,rows)
plt.show()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

# %%
np.random.randn(1000, 4).shape
# Out:
# (1000, 4)

# %%
#area plots
df = pd.DataFrame(np.random.rand(10, 4), columns=['p', 'q', 'r', 's'])
df.plot(kind='area')

# %%
np.random.rand(10, 4).shape
# Out:
# (10, 4)

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['p', 'q', 'r', 's'])
df.plot(kind='area', stacked=False)

# %%
#bubble chart
#here s is size for the plotted points
# A bubble chart is basically a scatter plot with an additional dimension.
df = pd.DataFrame(np.random.randn(500, 3), columns=['a', 'b', 'c'])
df.plot(kind='scatter',x='a',y='b',s=df['c']*400)
# Out:
# C:\Users\Poori\AppData\Roaming\Python\Python36\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
#trellis plot
import os
#os.chdir("C:\\Users\\Poori\\Desktop\\Udemy\\A-Z Machine learning Kaggle\\Github\\DataSet")
os.chdir("C:\\Users\\Poori\\Desktop\\Udemy\\A-Z Machine learning Kaggle\\Github\\Python Basics\\Course Files\\datacode")

# %%
import pandas as pd
coffee=pd.read_csv("coffee_info.csv")
coffee.head()
# Out:
#    Person_ID  Cups_Per_Week   Age Gender Employment    Education   Income  \
# 0          5              1  60.0      F   fulltime  high school  45000.0
# 1          6              1  40.0      F   fulltime  high school  46000.0
# 2          9              3   NaN      F   fulltime  high school  47000.0
# 3         14              5  20.0      F   fulltime   gradschool  65000.0
# 4         15              0  50.0      F   fulltime  high school  46000.0
#
#    Married Own_Home Smoker Favourite_NonAlc_Drink     Veg  cup_tea  spend_food
# 0  married       no    yes                    tea  nonveg        0       11787
# 1  married       no     no                  other     veg        6       18674
# 2  married       no     no                 coffee     veg        1       14814
# 3   single       no    yes              softdrink  nonveg        0       22997
# 4  married      yes     no                 coffee  nonveg        5       14606

# %%
coffee['Own_Home']=coffee['Own_Home'].map( {'yes':1, 'no':0})
coffee.head()
# Out:
#    Person_ID  Cups_Per_Week   Age Gender Employment    Education   Income  \
# 0          5              1  60.0      F   fulltime  high school  45000.0
# 1          6              1  40.0      F   fulltime  high school  46000.0
# 2          9              3   NaN      F   fulltime  high school  47000.0
# 3         14              5  20.0      F   fulltime   gradschool  65000.0
# 4         15              0  50.0      F   fulltime  high school  46000.0
#
#    Married  Own_Home Smoker Favourite_NonAlc_Drink     Veg  cup_tea  \
# 0  married         0    yes                    tea  nonveg        0
# 1  married         0     no                  other     veg        6
# 2  married         0     no                 coffee     veg        1
# 3   single         0    yes              softdrink  nonveg        0
# 4  married         1     no                 coffee  nonveg        5
#
#    spend_food
# 0       11787
# 1       18674
# 2       14814
# 3       22997
# 4       14606

# %%
coffee['Smoker']=coffee['Smoker'].map( {'yes':1, 'no':0})
coffee.head()
# Out:
#    Person_ID  Cups_Per_Week   Age Gender Employment    Education   Income  \
# 0          5              1  60.0      F   fulltime  high school  45000.0
# 1          6              1  40.0      F   fulltime  high school  46000.0
# 2          9              3   NaN      F   fulltime  high school  47000.0
# 3         14              5  20.0      F   fulltime   gradschool  65000.0
# 4         15              0  50.0      F   fulltime  high school  46000.0
#
#    Married  Own_Home  Smoker Favourite_NonAlc_Drink     Veg  cup_tea  \
# 0  married         0       1                    tea  nonveg        0
# 1  married         0       0                  other     veg        6
# 2  married         0       0                 coffee     veg        1
# 3   single         0       1              softdrink  nonveg        0
# 4  married         1       0                 coffee  nonveg        5
#
#    spend_food
# 0       11787
# 1       18674
# 2       14814
# 3       22997
# 4       14606

# %%
#from pandas.plotting import rplot
#plot = rplot.RPlot(tips_data, x='total_bill',y='tip')
#plot.add(rplot.TrellisGrid(['Own_Home', 'Smoker']))
#plot.add(rplot.GeomHistogram())

# %%
#from pandas.plotting import rplot

# %%
#plot = rplot.RPlot()

# %%
from pandas.plotting import scatter_matrix

# %%
np.linspace(0, 10, 100).shape
# Out:
# (100,)

# %%
#piechart
sizes = [22.6, 9.5, 47.4, 20.5]
labels = ['A', 'B', 'C', 'D']
colors = ['green', 'yellow', 'blue', 'orange']
plt.pie(sizes, colors=colors,autopct='%1.1f%%', shadow=True)
plt.legend(labels,loc='best')
plt.show()

# %%
#Doughnut Chart
sizes = [22.6, 9.5, 47.4, 20.5]
labels = ['A', 'B', 'C', 'D']
colors = ['green', 'yellow', 'blue', 'orange']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, colors= colors, autopct='%1.1f%%', startangle=90)
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
ax1.axis('equal')
plt.legend(labels)
plt.tight_layout()
plt.show()
